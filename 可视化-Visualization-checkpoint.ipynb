# %% [markdown]
# # 可视化

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %% [markdown]
# 这里使用matplotlib中的'ggplot'风格。

# %%
matplotlib.style.use('ggplot')

# %% [markdown]
# 这里仅仅提供pandas中基本的画图手段。

# %% [markdown]
# ## plot() 基本的画图方法

# %% [markdown]
# Series和DataFrame中的plot()方法是plt.plot()的封装。

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %% [markdown]
# 如果对象的索引是日期，会自动调用gcf().autofmt_xdate()得到如上图中的我们期望的x坐标。

# %% [markdown]
# 对于DataFrame对象，plot()方法能方便地对所有列画图。

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))

# %%
df = df.cumsum()

# %%
plt.figure() #重新画图
df.plot()

# %% [markdown]
# 如果要将DataFrame中某两列作为x轴和y轴画图，也很简单。

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()

# %%
df3['A'] = pd.Series(list(range(len(df))))

# %%
df3.head()
# Out:
#           B         C  A
# 0 -1.016772 -1.075062  0
# 1 -2.187695 -1.547621  1
# 2 -1.716406 -2.094751  2
# 3 -1.351664 -2.104897  3
# 4 -0.666918 -2.487674  4

# %%
plt.figure()
df3.plot(x='A', y='B')

# %% [markdown]
# ## 其他类型的图

# %% [markdown]
# plot()方法除了基本的折线图，还能画多种类型的图，使用**kind参数选择图像的类别**：
#
# * 'bar'或者'barh': 条形图
# * 'hist': 直方图
# * 'box': boxplot
# * 'kde'或'density': 密度图
# * 'area': 区域图
# * 'scatter': 散点图
# * 'hexbin': hexagonal bin
# * 'pie': 饼状图

# %% [markdown]
# 看一下例子：

# %%
plt.figure()

# %%
df.ix[5].plot(kind='bar')
plt.axhline(0, color='k')

# %% [markdown]
# 对于DataFrame来说，除了plot()方法中的kind参数可以选择图像的类别，pandas还将各种图像种类作为了属性。
#
# DataFrame.plot.<kind> == DataFrame.plot(kind='')

# %%
df = pd.DataFrame()

# %% [markdown]
# df.plot.<TAB>
#
# df.plot.area     df.plot.barh     df.plot.density  df.plot.hist     df.plot.line     df.plot.scatter
#
# df.plot.bar      df.plot.box      df.plot.hexbin   df.plot.kde      df.plot.pie

# %% [markdown]
# 除了使用kind参数，对于某些图像种类也有自己对应的方法：DataFrame.hist(), DataFrame.boxplot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))

# %% [markdown]
# ### 条形图 bar

# %% [markdown]
# 对于非时间序列数据，你可能想要作出条形图。

# %%
plt.figure()
df.ix[0].plot.bar()
plt.axhline(0, color='k')

# %% [markdown]
# DataFrame的plot.bar()方法也可以作出多列的条形图。

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=list('abcd'))

# %%
df2.plot.bar()

# %%
df2.plot(kind='bar')

# %% [markdown]
# 想要得到堆积形式的条形图，使用stacked参数。

# %%
df2.plot.bar(stacked=True)

# %%
df2.plot(kind='bar', stacked=True)

# %% [markdown]
# 想要得到水平的条形图，使用barh()方法。

# %%
df2.plot.barh(stacked=True)

# %% [markdown]
# ### 直方图

# %% [markdown]
# 使用DataFrame.plot.hist() Series.plot.hist()方法能作出直方图。

# %%
df4 = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000),
                     'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

# %%
plt.figure()

# %%
df4.plot.hist(alpha=0.5)

# %% [markdown]
# hist()也有stacked=True, 间隔大小可以使用bins参数调整。

# %%
plt.figure()

# %%
df4.plot.hist(stacked=True, bins=20)

# %% [markdown]
# 你可以给hist()方法传递matplotlib hist中的参数，比如，水平作图和累积直方图。

# %%
plt.figure()

# %%
df4['a'].plot.hist(orientation='horizontal', cumulative=True)

# %%
plt.figure()

# %%
df['A'].diff().hist()

# %% [markdown]
# 使用DataFrame.hist()作出各列的直方图，

# %%
plt.figure()

# %%
df.diff().hist(color='k', alpha=0.5, bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000F3614A8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000FDAB8D0>]], dtype=object)

# %%
data = pd.DataFrame(np.random.randn(1000))
data.hist(by=np.random.randint(0,4,1000), figsize=(6,4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000FFF0518>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010B242B0>]], dtype=object)

# %% [markdown]
# ### 盒图 box plot

# %% [markdown]
# Series.plot.box() DataFrame.plot.box() DataFrame.boxplot()可以作出盒图来可视化每一列值分布。

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E']) #均匀分布

# %%
df.plot.box()

# %% [markdown]
# 盒子的颜色可以通过color参数修改，各部分也可以使用不同颜色，使用字典传递。

# %%
color = dict(boxes='DarkGreen', whiskers='DarkOrange',
                 medians='DarkBlue', caps='Gray')

# %%
df.plot.box(color=color, sym='r+')

# %% [markdown]
# ### 区域图 area plot

# %% [markdown]
# 创建区域图的方法有 Series.plot.area(), DataFrame.plot.area()。区域图默认是堆积状态的，为了能够做出堆积的区域图，这就要求每列的值要么全部是正数要么全部是负数。

# %% [markdown]
# 如果输入含有NaN，会被默认填充为0.如果你想画图前去掉这些NaN或者填充其他值，可以在作图前使用dataframe.dropna(), dataframe.fillna()方法。

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=list('abcd'))

# %%
df.plot.area()

# %% [markdown]
# 如果想要画出不是堆积形态的区域图，使用参数stacked=False, Alpha值默认为0.5。

# %%
df.plot.area(stacked=False)

# %% [markdown]
# ### 散点图 Scatter Plot

# %% [markdown]
# 可以使用DataFrame.plot.scatter()画散点图。散点图要求x、y轴的列都是数值类型。x、轴的设定可以直接通过参数x、y设定。

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=list('abcd'))

# %%
df.plot.scatter(x='a', y='b')

# %% [markdown]
# 一幅散点图中也可以画出多组散点图，方法很简单，使用ax参数即可。为了不混淆不同组的点，提醒一下使用color和label参数区别开。

# %%
ax = df.plot.scatter(x='a', y='b', color='DarkBlue', label='Group 1')
df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2', ax=ax)

# %% [markdown]
# 颜色的设定 还可以通过scatter()方法中参数c 选择DataFrame中一列来设定颜色。

# %%
df.plot.scatter(x='a', y='b', c='c', s=50)

# %%
df.head()
# Out:
#           a         b         c         d
# 0  0.963893  0.638100  0.633086  0.769565
# 1  0.466054  0.852057  0.865324  0.847456
# 2  0.673793  0.340190  0.182500  0.979140
# 3  0.826840  0.356790  0.749341  0.378846
# 4  0.214263  0.658183  0.554387  0.644186

# %% [markdown]
# scatter()还有很多参数，比如每个点的大小，可以通过某一列的值来设定每个点/气泡的大小。

# %%
df.plot.scatter(x='a', y='b', s=df['c']*200)

# %% [markdown]
# ### 六边形图 Hexagonal Bin Plot

# %% [markdown]
# 创建六边形图的方法是DataFrame.plot.hexbin()。 六边形可以作为散点图的替代，特别是当数据大小分布过于密集，此时散点图很难区分各个点，六边形就是很好的一种方式。

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=list('ab'))

# %%
df['b'] = df['b'] + np.arange(1000)

# %%
df.plot.hexbin(x='a', y='b', gridsize=25)

# %% [markdown]
# hexbin()方法中参数gridsize很有用，它控制x轴上六边形的个数，默认是100.gridsize越大，区间个数越多同时大小也越小。

# %% [markdown]
# ### 饼图 Pie Plot

# %% [markdown]
# 创建饼图的方法有 DataFrame.plot.pie()和Series.plot.pie()。如果数据中有NaN，作图前会被默认填充为0. 如果数据中有负值则会引起ValueError。

# %%
series = pd.Series(3*np.random.rand(4), index=['a', 'b', 'c', 'd'], name='series')

# %%
series.plot.pie(figsize=(6,6))

# %%
series
# Out:
# a    2.729795
# b    0.997533
# c    0.668339
# d    1.230719
# Name: series, dtype: float64

# %% [markdown]
# DataFrame.plot.pie()要求通过y参数确定要作图的列或者subplots=True则会把每一列都作饼图。

# %%
df = pd.DataFrame(3 * np.random.rand(4,2), index=list('abcd'), columns=list('xy'))

# %%
df.plot.pie(subplots=True, figsize=(8,4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000012D09EF0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012DC97B8>], dtype=object)

# %% [markdown]
# 使用legend=False， 可以去掉说明。

# %% [markdown]
# 使用labels和colors参数来定制每个扇区。

# %%
series.plot.pie(labels=['AA', 'BB', 'CC', 'DD'], colors=['r', 'g', 'b', 'c'],
                    autopct='%.2f', fontsize=20, figsize=(6, 6))

# %% [markdown]
# 如果pie()接收的数值总和小于1，会作出扇区。

# %%
series = pd.Series([0.1] * 4, index=['a', 'b', 'c', 'd'], name='series2')

# %%
series.plot.pie(figsize=(6, 6))

# %% [markdown]
# ## 处理缺失值

# %% [markdown]
# 数据中难免会有缺失值，不同图形方法有不同的处理方法：
#
#
# |    图形     | NaN处理方法  |
# | ------------- |:-------------:|
# | Line      | 在NaN处留有缺口|
# | Line(stacked)      | 填充0|
# | 条形图|填充0|
# |散点图|丢弃|
# |直方图|丢弃|
# |盒图|丢弃|
# |区域图|填充0|
# |KDE|丢弃|
# |六边形|丢弃|
# |饼图|填充0|

# %% [markdown]
# 如果默认处理手段不是你想要的，你可以在作图前使用fillna()或者dropna()方法来自己处理。

# %% [markdown]
# ## 作图工具

# %% [markdown]
# 作图工具来自pandas.tools.plotting, 接收Series或DataFrame对象作为参数。

# %% [markdown]
# ### 散点矩阵作图

# %% [markdown]
# 使用pandas.tools.plotting中的scatter_matrix方法创建散点图矩阵。

# %%
from pandas.tools.plotting import scatter_matrix

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])

# %%
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000012D09AC8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000014665A90>]], dtype=object)

# %% [markdown]
# ### 密度图 Density Plot

# %% [markdown]
#  创建密度图的方法有Series.plot.kde()和DataFrame.plot.kde()。

# %%
ser = pd.Series(np.random.randn(1000))

# %%
ser.plot.kde()

# %% [markdown]
# ### 安德鲁曲线 Andrews Curves

# %%
from pandas.tools.plotting import andrews_curves

df = pd.DataFrame(np.random.randn(100,3), columns=['A','B', 'C'])
df['X'] = np.random.choice(['Alpha', 'Beta', 'Theta'], size=100)

# %%
plt.figure()

andrews_curves(df, 'X')

# %% [markdown]
# ### 并行坐标 Parallel Coordinates

# %% [markdown]
# 并行坐标用于对多变量数据作图。可以观察聚类簇。 每条竖线代表一个属性。

# %%
from pandas.tools.plotting import parallel_coordinates

df = pd.DataFrame(np.random.randn(100,3), columns=['A','B', 'C'])
df['X'] = np.random.choice(['Alpha', 'Beta', 'Theta'], size=100)
plt.figure()

parallel_coordinates(df, 'X')

# %% [markdown]
# ### Lag图

# %% [markdown]
# **Lag图用于检查数据集或时间序列是否是随机的**。随机数据在Lag图中不会表现出任何的结构。而结构暗示着数据是非随机的。

# %%
from pandas.tools.plotting import lag_plot
plt.figure()

# %%
data = pd.Series(0.1 * np.random.rand(1000) +
        0.9 * np.sin(np.linspace(-99 * np.pi, 99 * np.pi, num=1000)))

# %%
lag_plot(data)

# %% [markdown]
# ### 自相关图 Autocorrelation Plot

# %% [markdown]
# 自相关图通常用于检测时间序列中的随机性。通过计算数据在不同时间点的自相关。如果时间序列是随机的，自相关结果应该近似0。反之。

# %%
from pandas.tools.plotting import autocorrelation_plot

# %%
plt.figure()

# %%
data = pd.Series(0.7 * np.random.rand(1000) +
       0.3 * np.sin(np.linspace(-9 * np.pi, 9 * np.pi, num=1000)))

# %%
autocorrelation_plot(data)

# %% [markdown]
# ### Bootstrap Plot

# %% [markdown]
# Bootstrap Plot用于可视化评估统计指标(比如平均值、中值等)的不稳定性。 通过从数据中随机选择固定大小的样本计算统计指标，然后不断重复此过程。

# %%
from pandas.tools.plotting import bootstrap_plot

# %%
data = pd.Series(np.random.rand(1000))

# %%
bootstrap_plot(data, size=50, samples=500, color='grey')

# %% [markdown]
# ### RadViz

# %% [markdown]
# RadViz是一种对多变量数据可视化的方法。基于一个简单的spring tension minimization algorithm.

# %%
from pandas.tools.plotting import radviz
df = pd.DataFrame(np.random.randn(100,3), columns=['A','B', 'C'])
df['X'] = np.random.choice(['Alpha', 'Beta', 'Theta'], size=100)
plt.figure()
radviz(df, 'X')

# %% [markdown]
# ## 作图格式 Plot Formatting

# %% [markdown]
# 大多数方法有一些参数进行图形的布局等定制。

# %%
plt.figure(); ts.plot(style='k--', label='Series');

# %% [markdown]
# ### 控制 说明 Controlling the Legend

# %% [markdown]
# 使用lengend=False关闭图形说明。

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))

# %%
df = df.cumsum()

# %%
df.plot(legend=False)

# %% [markdown]
# ### 坐标轴范围

# %% [markdown]
# 使用logy来确定Y轴的log-scale。logx设定X轴的log-scale。

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods = 1000))

# %%
ts=np.exp(ts.cumsum())

# %%
ts.plot(logy=True)

# %% [markdown]
# ### 设定两个y轴

# %% [markdown]
# 通过设定secondary_y参数来设定第二个y轴。

# %%
df.A.plot()
df.B.plot(secondary_y=True, style='g')

# %% [markdown]
# 对DataFrame对象作图时，通过secondary_y参数来设定列。

# %%
plt.figure()

# %%
ax = df.plot(secondary_y=['A', 'B'])
ax.set_ylabel('CD scale')
ax.right_ax.set_ylabel('AB scale')

# %% [markdown]
# 注意到secondary_y对应的列在legend中默认带有right，可以通过 mark_right=False参数来关闭。

# %%
plt.figure()
df.plot(secondary_y=['A', 'B'], mark_right=False)

# %% [markdown]
# ### 子图

# %% [markdown]
# DataFrame中的每一个Series可以做出一个子图，使用subplots参数即可。

# %%
df.plot(subplots=True, figsize=(6,6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000002A7D3EF0>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000002AA4DF60>], dtype=object)

# %% [markdown]
# ### 误差线图 Error Bar

# %% [markdown]
# Series.plot()和DataFrame.plot()方法支持误差线图。

# %%
ix3 = pd.MultiIndex.from_arrays([['a', 'a', 'a', 'a', 'b', 'b', 'b', 'b'], ['foo', 'foo', 'bar', 'bar', 'foo', 'foo', 'bar', 'bar']], names=['letter', 'word'])

# %%
df3 = pd.DataFrame({'data1': [3, 2, 4, 3, 2, 4, 3, 2], 'data2': [6, 5, 7, 5, 4, 5, 6, 5]}, index=ix3)
gp3 = df3.groupby(level=('letter', 'word'))

means = gp3.mean()

# %%
errors = gp3.std()

# %%
means
# Out:
#              data1  data2
# letter word
# a      bar     3.5    6.0
#        foo     2.5    5.5
# b      bar     2.5    5.5
#        foo     3.0    4.5

# %%
errors
# Out:
#                 data1     data2
# letter word
# a      bar   0.707107  1.414214
#        foo   0.707107  0.707107
# b      bar   0.707107  0.707107
#        foo   1.414214  0.707107

# %%
fig, ax = plt.subplots()
means.plot.bar(yerr=errors, ax=ax)
